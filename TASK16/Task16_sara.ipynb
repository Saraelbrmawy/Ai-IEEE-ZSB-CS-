# %%
df = pd.read_excel('ZF_Elec_Responses.xlsx')
df
# Out:
#                  Timestamp    Full Name (3 names at least)   Phone Number  \
# 0  2022-05-12 19:30:19.458           Mohamed Monir Mohamed    01210933802
# 1  2022-05-12 20:01:06.995        Mohammed Salah Aboshosha    01027463950
# 2  2022-05-12 20:15:51.354  mohamed salah fathy abdelhamid    01004257855
# 3  2022-05-12 20:17:26.297  Omar Saad Mohamed Saad Soliman    01149493914
# 4  2022-05-12 20:30:14.318            ماجد علاء السيد محمد    01013414668
# ..                     ...                             ...            ...
# 85 2022-05-24 22:04:39.898               Ahmed Atef Saleh     01280149017
# 86 2022-05-24 23:26:36.607                محمد السيد الربع    01285688383
# 87 2022-05-25 00:08:13.074   احمد عصام فاروق ابوالخير احمد    01146907098
# 88 2022-05-25 10:50:32.161        اياد محمد عبدالحليم محمد    01021463089
# 89 2022-05-25 20:58:33.757         Muhammad Samir Muhammad  +201096390741
#
#                            Email                 Faculty - Department  \
# ...

# %%
##Number of students who filled out the form=90
df.shape[0]
# Out:
# 90

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df.isnull().sum()
# Out:
# Timestamp                                               0
# Full Name (3 names at least)                            0
# Phone Number                                            0
# Email                                                   0
# Faculty - Department                                    0
# Academic Year                                           0
# Date of birth                                           0
# Facebook URL                                            0
# LinkedIn URL (optional)                                32
# What do you know about Z Fast Racing Team?              0
# How did you hear about us?                              0
# Do you have any volunteering experience?                0
# If yes, what is your volunteering experience?           0
# What do you know about electrical vehicle ?             7
# What do you know about competition we participate ?    17
# What do you seek to learn by joining Z Fast Team?       0
# ...

# %%
#rename columns names
df = df.rename(columns={'Full Name (3 names at least)':'Full_Name',
    'LinkedIn URL (optional)':'LinkedIn_URL',
                        'What do you know about Z Fast Racing Team?': 'Zfast_racingteam',
                        'How did you hear about us?': 'Hear_us',
                        'Do you have any volunteering experience?': 'Volunteering_experience',
                        'What do you know about electrical vehicle ?': 'electrical_vehicle',
                        'Do you have any volunteering experience?': 'Volunteering_experience',
                        'If yes, what is your volunteering experience?': 'Your_volunteering',
                        'What do you know about competition we participate ?': 'Competition',
                        'What do you seek to learn by joining Z Fast Team?': 'Soughts',
                       'Any questions?': 'Questions'
                       })
df.head()
# Out:
#                 Timestamp                       Full_Name Phone Number  \
# 0 2022-05-12 19:30:19.458           Mohamed Monir Mohamed  01210933802
# 1 2022-05-12 20:01:06.995        Mohammed Salah Aboshosha  01027463950
# 2 2022-05-12 20:15:51.354  mohamed salah fathy abdelhamid  01004257855
# 3 2022-05-12 20:17:26.297  Omar Saad Mohamed Saad Soliman  01149493914
# 4 2022-05-12 20:30:14.318            ماجد علاء السيد محمد  01013414668
#
#                           Email         Faculty - Department Academic Year  \
# 0      mohameddobea13@gmail.com       Electrical engineering      3rd year
# 1  mohamedaboshosha12@gmail.com     Engineering - Electrical      2nd year
# 2      medosalahmedo4@gmail.com  engengineering-mechatronics      3rd year
# 3          mingosos13@gmail.com                 Mechatronics      3rd year
# 4        Magedalaazsc@gmail.com    كلية الهندسة - أولى كهربا      2nd year
#
#   Date of birth                                   Facebook URL  \
# ...

# %%
df['LinkedIn_URL']=df['LinkedIn_URL'].fillna('nolinkedIn')

# %%
#students don't have linkedin
df[df['LinkedIn_URL']=='nolinkedIn']
# Out:
#                  Timestamp                              Full_Name  \
# 52 2022-05-16 16:12:21.662                محمد عصمت عبدالله    01012069129
# 62 2022-05-17 10:09:18.156  Ahmed Mohamed Fathy abdelhameed    01205397427
# 65 2022-05-17 21:17:36.493             Norhan mohsen soliman   01068273700
# 67 2022-05-17 23:01:30.759              Ahmed shady elsayed    01030705013
# 68 2022-05-18 12:54:26.201   Ahmed yousry mohamed eldidamony   01020810742
# 83 2022-05-24 18:40:44.285                 Mohamed Salah Eid  010222388938
#
#                           Email  \
# 41       alaawahbaa13@gmail.com
# 52  mahmoudesmat20029@gmail.com
# 62        ahmedkhad4@gmail.com
# 65   nourhanmohsen629@gmail.com
# 67      medoshady153@gmail.com
# 68     ahmeddidamony9@gmail.com
# 83     mohamedarqan75@gmail.com
#
#                                Faculty - Department Academic Year  \
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                  0
# Full_Name                  0
# Phone Number               0
# Email                      0
# Faculty - Department       0
# Academic Year              0
# Date of birth              0
# Facebook URL               0
# LinkedIn_URL               0
# Zfast_racingteam           0
# Hear_us                    0
# Volunteering_experience    0
# Your_volunteering          0
# electrical_vehicle         0
# Competition                0
# Soughts                    0
# Questions                  0
# dtype: int64

# %%
#faculty and department for students
df['Faculty - Department'].unique()
# Out:
# array(['Electrical engineering', 'Engineering - Electrical',
#        'engengineering-mechatronics', 'Mechatronics',
#        'كلية الهندسة - أولى كهربا',
#        'Faculty of Engineering ZU- Electrical Department ',
#        'الهندسه قسم كهرباء', 'engineering-electric',
#        'Electrical engineering ',
#        'Electrical department , faculty of engineering ', 'Electrical',
#        'Engineering - Electrical ', 'Engineering-prep',
#        'Faculty of electrical engineering', 'Engineering-Electrical',
#        'Faculty of engineering - Electrical power and Machines ',
#        'CIC- mechatronics', 'Prep',
#        'Faculty of engineering _ Electrical department ',
#        'Engineering _ prep year', 'Engineering - Zagazig',
#        'Electrical Engineering ', 'Electric department ',
#        'engineering- electric department ',
#        'Faculty of engineering - prepatory',
#        'Air defence college/communication and electronics',
# ...

# %%
#Academic Year for students
plt.bar(df['Academic Year'].value_counts().index, df['Academic Year'].value_counts().values)
plt.show()

# %%
df['LinkedIn_URL'] = df['LinkedIn_URL'].apply(lambda x: "Null" if len(x) < 25 else x)
df['LinkedIn_URL'].value_counts()
# Out:
# Null                                                         38
# https://www.linkedin.com/in/mostafa-m-radwan                  2
# https://www.linkedin.com/in/mohamed-dobea-a9116b21b           1
# https://www.linkedin.com/in/manalalyabdallah                  1
# https://www.linkedin.com/in/aya-khaled-b7a1b8231              1
# https://www.linkedin.com/in/ahmed-saber-265209227             1
# https://www.linkedin.com/in/ahmedabonassar/                   1
# https://www.linkedin.com/in/mazen-ahmed174/                   1
# https://www.linkedin.com/in/mohamedelsharkawy2001             1
# https://www.linkedin.com/in/mena-gamal                        1
# https://www.linkedin.com/in/ahmed-fathy-3554b8230             1
# https://www.linkedin.com/in/mohamed-o-elsayed/                1
# https://www.linkedin.com/in/norhan-mohsen-309561235           1
# https://www.linkedin.com/in/fatma-yosry-elzeny-92a48b1b5      1
# https://www.linkedin.com/in/eng-moustafa-salah-3155521b6      1
# ...

# %%
df['Zfast_racingteam'] = df['Zfast_racingteam'].apply(lambda x: "Null" if len(x) < 25 else x)
df['Zfast_racingteam'].value_counts()
# Out:
# Null                                                                                                                                                                                                                                                           7
# Z-Fast is the team that represents Zagazig University in EVER Competition.                                                                                                                                                                                     2
# Founded in 2018. It manufactures electric vehicles and participates in them in races...                                                                                                                                                                        1
# ...

# %%
df['Competition'] = df['Competition'].apply(lambda x: "Null" if len(x) < 20 else x)
df['Competition'].value_counts()
# Out:
# Null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           29
# EVER is a competition for design and manufacturing an electrical car.                                                                                                                                                                                                                                                                                                                                                                                                                                           3
# ...

# %%
df['electrical_vehicle'].unique()
# Out:
# array(['It is an automotive vehicle that uses one or more electric motors for propulsion. It can be powered by a collector system, with electricity from extravehicular sources, or it can be powered autonomously by a battery sometimes charged by solar panels, or by converting fuel to electricity using fuel cells or a generator.',
#        'To sum up electrical vehicles are vehicles that are either partially or fully powered on electric power, have low running costs as they have less moving parts for maintaining and also very environmentally friendly as they use little or no fossil fuels (petrol or diesel).\n\n',
# ...

# %%
df['electrical_vehicle'] = df['electrical_vehicle'].apply(lambda x: "Null" if len(x) < 20 else x)
df['electrical_vehicle'].value_counts()
# Out:
# Null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 10
# ...

# %%
#The number of students who actually asked questions 
questions = df[df['Questions'].str.endswith('?')]
questions
# Out:
#                  Timestamp                Full_Name   Phone Number  \
# 17 2022-05-12 22:46:16.815         Omar Tarek Fawzy    01272000099
# 49 2022-05-15 23:10:52.555    Aya Khaled Goda Sanad    01122080979
# 89 2022-05-25 20:58:33.757  Muhammad Samir Muhammad  +201096390741
#
#                         Email                 Faculty - Department  \
# 17   ana.tarekelgan@gmail.com                    CIC- mechatronics
# 49    ayakhaled7420@gmail.com  Engineering, Electrical engineering
# 89  MuhammadSawalhy@gmail.com  Engineering - Electrical (2nd year)
#
#    Academic Year Date of birth  \
# 17      3rd year    2000-11-02
# 49      2nd year    2002-02-17
# 89      3rd year    2001-05-20
#
#                                          Facebook URL  \
# 17                https://www.facebook.com/Ghazal.a2a
# 49  https://www.facebook.com/profile.php?id=100055...
# 89                https://www.facebook.com/ms.2052001
#
#                                         LinkedIn_URL  \
# ...

# %%
#how to hear about the team
facebook_rows = df[df['Hear_us'].str.contains('Facebook')]
Friends_rows = df[df['Hear_us'].str.contains('Friends')]
Faculty_colleagues_rows = df[df['Hear_us'].str.contains('Faculty colleagues')]
Instagram_rows = df[df['Hear_us'].str.contains('Instagram')]


print(facebook_rows.shape[0])
print(Friends_rows.shape[0])
print(Faculty_colleagues_rows.shape[0])
print(Instagram_rows.shape[0])
# Out:
# 73
# 53
# 35
# 2

# %%
#Determine the gender of the student
df['Full_Name'].unique()
# Out:
# array(['Mohamed Monir Mohamed', 'Mohammed Salah Aboshosha',
#        'mohamed salah fathy abdelhamid', 'Omar Saad Mohamed Saad Soliman',
#        'ماجد علاء السيد محمد', 'Mostafa Mohamed Ahmed ',
#        'محمد احمد محمد السيد', 'احمد حسام محمد عطية ',
#        'ابراهيم محمد ابراهيم محمد ', 'Mohamed salah mohamed',
#        'محمود احمد محمود حسن', 'محمد ايمن محمد', 'Ali Abdelzez Zaghlol',
#        'Mahmoud Ammar Abd Elaziz Hassan', 'محمد جمال سليم',
#        'Khalid walid mohammed alazouni', 'Mohamed Ali Ahmed',
#        'Omar Tarek Fawzy', 'احمد عبد المجيد محمد محمد منصور ',
#        'Ahmed Reda Ebrahim Abdulrhman Tahoon ', 'Mina Fayez Khalil',
#        'Mohamed ahmed abdull-haleam', 'Mahmoud Abdelnaby mohamed',
#        'Abdulrahman Omar Hassan ', 'اية رضا اليمانى ',
#        'Abdulrahman Amr Sleem', 'Abdelkader Ahmed Ismail Mohamed',
#        ' Hady hisham mahmoud ', 'Mohamed Ali Bayoumi ',
#        'Hesham Khaled Salah Mohamed', 'Menna Allah Mohamed Ibrahem',
# ...

# %%
#Number of students participating in a volunteer team
df['Volunteering_experience'].unique()
df['Volunteering_experience'].value_counts()
# Out:
# Yes    52
# No     38
# Name: Volunteering_experience, dtype: int64

# %%
df['Your_volunteering'].unique()
# Out:
# array(['I have volunteered with AIESEC SOLVAKIAN organisation to Exchange our cultural online.',
#        'Joined zag eng family for about one and half year as an academic member then became vice head of HR committee. \nJoined Hult prize Zagazig University as a project management member for about 4 months.\nJoined IEEE ZSB as a RAS committee embedded track member.',
#        'this will be first time', 'no thing',
#        'Zag Eng team ( for 6 months - now)\nResala charity ( for 2 weeks)',
#        'PR at Zegzag ', 'No ', 'no ', 'لم اشارك ', 'No',
#        "I don't have any volunteering experience ",
#        'I worked at ZUFS ( Zagazig university formula student) \n& i work in ZESU (Zagazig university student union ) ',
#        'Ieee ZSB , zigzag , YLY',
#        "I don't have any volunteering experience", 'It is no',
#        'I am a volunteer in the Life Makers Charitable Association',
#        'In formula student gasoline - ever mechanical and electrical',
# ...

# %%
# students don't know about compition and electrical vehicle
dfs= df[(df.Competition=='Null')& (df.electrical_vehicle=='Null')]
dfs
# Out:
#                  Timestamp                        Full_Name  Phone Number  \
# 20 2022-05-12 23:54:07.317                Mina Fayez Khalil   01228339876
# 26 2022-05-13 09:25:57.114  Abdelkader Ahmed Ismail Mohamed   01148560567
# 41 2022-05-14 22:20:48.384       Alaa Emad Abdelhamid Wahba   01113472244
# 52 2022-05-16 16:12:21.662               محمد عصمت عبدالله    01012069129
# 65 2022-05-17 21:17:36.493            Norhan mohsen soliman   01068273700
# 67 2022-05-17 23:01:30.759             Ahmed shady elsayed    01030705013
# 68 2022-05-18 12:54:26.201  Ahmed yousry mohamed eldidamony   01020810742
# 83 2022-05-24 18:40:44.285                Mohamed Salah Eid  010222388938
# 88 2022-05-25 10:50:32.161         اياد محمد عبدالحليم محمد   01021463089
#
#                                  Email  \
# 20            minafayez9876@gmail.com
# 26  abdelkader.ismail21@beng.bu.edu.eg
# 41              alaawahbaa13@gmail.com
# 52         mahmoudesmat20029@gmail.com
# ...

# %% [markdown]
# The number of students who filled out the form is 90 students
# Most students are male
# Most of the students are in the faculty of engineering and the Department of electricity
# Most of the students are second year and third year
# Only 3 students have questions
# 38 students without a LinkedIn account
# 28 students who have no knowledge of the competition
# 10 students have no knowledge of the electric vehicle
# 52 students participate in a volunteer team (57.8%)
# Most of the students knew about the team through Facebook, followed by friends
# There are a number of students(9) who did not answer some questions, so we can say that they should not be accepted:
# 1- Mina Fayez Khalil
# 2-Abdelkader Ahmed Ismail Mohamed
# 3-Alaa Emad Abdelhamid Wahba
# 4-محمد عصمت عبدالله
# 5-Norhan mohsen soliman
# 6-Ahmed shady elsayed
# 7-Ahmed yousry mohamed eldidamony
# 8-Mohamed Salah Eid
# 9-اياد محمد عبدالحليم محمد
