# %% [markdown]
# # EDA with Visuals
# Create visualizations to answer the questions below. Use the `winequality_edited.csv` dataset, which you should've created  in the previous quiz.

# %%
import pandas as pd
df=pd.read_csv("winequality_edited.csv")
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ### Which of the following feature variables appear skewed to the right? Fixed Acidity, Total Sulfur Dioxide, pH, Alcohol _____________________ (answer using plots) #answer=free_sulfur_dioxide,fixed-acidity

# %%
df['fixed_acidity'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Which of the following is most likely to have a positive impact on quality? Volatile Acidity, Residual Sugar, pH, Alcohol _____________________________ (answer using plots) anwser=alcohol

# %%
df.plot(x='quality',y='pH',kind='line')
# Out:
# <AxesSubplot:xlabel='quality'>

# %%
df.plot(x='quality',y='volatile_acidity',kind='line')
# Out:
# <AxesSubplot:xlabel='quality'>

# %%
df.plot(x='quality',y='residual_sugar',kind='line')
# Out:
# <AxesSubplot:xlabel='quality'>

# %%
df.plot(x='quality',y='alcohol',kind='line')
# Out:
# <AxesSubplot:xlabel='quality'>
